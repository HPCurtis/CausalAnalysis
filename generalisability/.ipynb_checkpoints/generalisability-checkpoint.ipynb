# %%
from pymc import Model, Binomial, Normal, MvNormal, math, Exponential, Beta, sample
import numpy as np
import pandas as pd
import pytensor.tensor as pt
from pytensor.tensor.linalg import cholesky
from utility import data_loader, data_cleaner, sample_dist
import arviz as az

# %%
berlin_data, vanautu_data, adult_data, child_data = data_loader()

# %%
d_berlin,
d_vanautu,
MA, 
pop_berlin,
pop_berlin_raw,
pop_vanautu_raw,
pop_vanautu = data_cleaner(berlin_data, vanautu_data,
                           adult_data, child_data)

# %%
# Create matrices with zeros
sample_berlin, sample_vanuatu = sample_dist(d_berlin, d_vanautu)

# %%
#Covaraince Kenrel defined for the paper and implemented in Stan.
MA = 20
age = d_berlin["Age_binned"].values - 1
outcome = d_berlin["choice"]
gender = d_berlin["gender"].values - 1
d_berlinf = d_berlin[d_berlin["gender"] == 1]
d_berlinm =d_berlin[d_berlin["gender"] == 2]
d_berlinf['Age_binned'] = d_berlinf["Age_binned"].astype(int)
d_berlinm['Age_binned'] = d_berlinm["Age_binned"].astype(int)
# Out:
# /tmp/ipykernel_204645/3536775231.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d_berlinf['Age_binned'] = d_berlinf["Age_binned"].astype(int)
# /tmp/ipykernel_204645/3536775231.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d_berlinm['Age_binned'] = d_berlinm["Age_binned"].astype(int)

# %%
P_pop = pop_berlin_raw
P_other = pop_vanautu_raw


def GPL(K, C, D, S, epsilon=1e-6):
    KR = np.arange(1, K + 1)
    Rho = C * pt.exp(-D * ((KR[:, None] - KR[None, :]) ** 2) / K ** 2)
    pt.fill_diagonal(Rho, 1)
    
    # Add a small diagonal perturbation
    Rho += epsilon * pt.eye(K)
    
    return S * cholesky(Rho)
    
with Model() as gp:
    # Priors for parameters
    alpha = Normal('alpha', mu=0, sigma=3, shape=2)
    eta = Exponential('eta', lam=2, shape=2)
    sigma = Exponential('sigma', lam=1, shape=2)
    rho = Beta('rho', alpha=10, beta=1, shape=2)

    # Gaussian process age effects
    age_effectf = MvNormal("age_effectf",
        mu=np.zeros(MA),
        chol=GPL(MA, rho[0], eta[0], sigma[0])#, shape = MA
    ) 

    age_effectm = MvNormal("age_effectm",
        mu=np.zeros(MA),
        chol=GPL(MA, rho[1], eta[1], sigma[1])#, shape = MA
    ) 
      
    # Linear model
    pf = math.invlogit(alpha[0] + age_effectf[ np.array(d_berlinf['Age_binned']) ] ) 
    pm = math.invlogit(alpha[1] + age_effectm[ np.array(d_berlinm['Age_binned']) ] ) 
    
    # Likelihood function
    outcome_obsf = Binomial('outcome_obsf', n=1, p = pf, observed = d_berlinf["choice"].values)
    outcome_obsm = Binomial('outcome_obsm', n=1, p = pm, observed = d_berlinm["choice"].values)

# %%
with gp:
     trace = sample(3000, tune=1000, chains=4, cores=4, init='adapt_diag', target_accept=0.99, nuts_sampler = "numpyro")
# Out:
# Compiling...
# Compilation time = 0:00:04.190455
# Sampling...
# Compiling.. :   0%|                                    | 0/4000 [00:00<?, ?it/s]
#   0%|                                                  | 0/4000 [00:00<?, ?it/s]
# Compiling.. :   0%|                                    | 0/4000 [00:00<?, ?it/s]
#
#   0%|                                                  | 0/4000 [00:00<?, ?it/s]
#
# Compiling.. :   0%|                                    | 0/4000 [00:00<?, ?it/s]
#
#
#   0%|                                                  | 0/4000 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|                                    | 0/4000 [00:00<?, ?it/s]
#
#
# Running chain 0:   0%|                                 | 0/4000 [00:05<?, ?it/s]
#
# Running chain 2:   0%|                                 | 0/4000 [00:05<?, ?it/s]
# Running chain 1:   0%|                                 | 0/4000 [00:05<?, ?it/s]
# Running chain 0:   5%|█▏                     | 200/4000 [00:16<03:36, 17.55it/s]
#
# Running chain 2:   5%|█▏                     | 200/4000 [00:17<03:43, 16.98it/s]
#
#
# Running chain 3:   5%|█▏                     | 200/4000 [00:17<03:52, 16.36it/s]
#
#
# Running chain 3:   5%|█▏                     | 200/4000 [00:29<03:52, 16.36it/s]
#
# Running chain 0:   5%|█▏                     | 200/4000 [00:29<03:36, 17.55it/s]
# Running chain 1:   5%|█▏                     | 200/4000 [00:29<03:34, 17.70it/s]
# Running chain 0:  10%|██▎                    | 400/4000 [00:34<04:27, 13.47it/s]
#
# Running chain 2:  10%|██▎                    | 400/4000 [00:34<04:30, 13.30it/s]
#
#
# Running chain 3:  10%|██▎                    | 400/4000 [00:34<04:34, 13.13it/s]
#
#
# Running chain 3:  10%|██▎                    | 400/4000 [00:49<04:34, 13.13it/s]
#
# Running chain 0:  10%|██▎                    | 400/4000 [00:49<04:27, 13.47it/s]
# Running chain 1:  10%|██▎                    | 400/4000 [00:49<04:27, 13.47it/s]
# Running chain 0:  15%|███▍                   | 600/4000 [00:52<04:41, 12.07it/s]
#
# Running chain 2:  15%|███▍                   | 600/4000 [00:52<04:42, 12.05it/s]
#
#
# Running chain 3:  15%|███▍                   | 600/4000 [00:53<04:45, 11.90it/s]
#
#
# Running chain 3:  15%|███▍                   | 600/4000 [01:09<04:45, 11.90it/s]
#
# Running chain 0:  15%|███▍                   | 600/4000 [01:09<04:41, 12.07it/s]
# Running chain 1:  15%|███▍                   | 600/4000 [01:09<04:40, 12.10it/s]
# Running chain 0:  20%|████▌                  | 800/4000 [01:12<04:44, 11.25it/s]
#
# Running chain 2:  20%|████▌                  | 800/4000 [01:12<04:45, 11.22it/s]
#
#
# Running chain 3:  20%|████▌                  | 800/4000 [01:13<04:49, 11.06it/s]
#
# Running chain 0:  20%|████▌                  | 800/4000 [01:29<04:44, 11.25it/s]
# Running chain 1:  20%|████▌                  | 800/4000 [01:29<04:43, 11.31it/s]
# Running chain 0:  25%|█████▌                | 1000/4000 [01:32<04:38, 10.78it/s]
#
# Running chain 2:  25%|█████▌                | 1000/4000 [01:32<04:38, 10.77it/s]
#
#
# Running chain 3:  25%|█████▌                | 1000/4000 [01:33<04:41, 10.66it/s]
#
#
# Running chain 3:  25%|█████▌                | 1000/4000 [01:49<04:41, 10.66it/s]
#
# Running chain 0:  25%|█████▌                | 1000/4000 [01:49<04:38, 10.78it/s]
# Running chain 1:  25%|█████▌                | 1000/4000 [01:49<04:37, 10.80it/s]
# Running chain 0:  30%|██████▌               | 1200/4000 [01:52<04:28, 10.41it/s]
#
# Running chain 2:  30%|██████▌               | 1200/4000 [01:53<04:29, 10.40it/s]
#
#
# Running chain 3:  30%|██████▌               | 1200/4000 [01:53<04:30, 10.36it/s]
# Running chain 0:  35%|███████▋              | 1400/4000 [02:13<04:16, 10.14it/s]
#
# Running chain 2:  35%|███████▋              | 1400/4000 [02:13<04:16, 10.14it/s]
#
#
# Running chain 3:  35%|███████▋              | 1400/4000 [02:14<04:17, 10.11it/s]
# Running chain 0:  40%|████████▊             | 1600/4000 [02:34<04:01,  9.92it/s]
#
# Running chain 2:  40%|████████▊             | 1600/4000 [02:34<04:01,  9.92it/s]
#
#
# Running chain 3:  40%|████████▊             | 1600/4000 [02:35<04:01,  9.92it/s]
# Running chain 0:  45%|█████████▉            | 1800/4000 [02:55<03:45,  9.76it/s]
#
# Running chain 2:  45%|█████████▉            | 1800/4000 [02:56<03:45,  9.76it/s]
#
#
# Running chain 3:  45%|█████████▉            | 1800/4000 [02:56<03:45,  9.76it/s]
# Running chain 0:  50%|███████████           | 2000/4000 [03:17<03:27,  9.63it/s]
#
# Running chain 2:  50%|███████████           | 2000/4000 [03:17<03:27,  9.62it/s]
#
#
# Running chain 3:  50%|███████████           | 2000/4000 [03:18<03:27,  9.62it/s]
# Running chain 0:  55%|████████████          | 2200/4000 [03:38<03:08,  9.54it/s]
#
# Running chain 2:  55%|████████████          | 2200/4000 [03:38<03:08,  9.53it/s]
#
#
# Running chain 3:  55%|████████████          | 2200/4000 [03:39<03:08,  9.54it/s]
# Running chain 0:  60%|█████████████▏        | 2400/4000 [04:00<02:49,  9.42it/s]
#
# Running chain 2:  60%|█████████████▏        | 2400/4000 [04:00<02:50,  9.40it/s]
#
#
# Running chain 0:  65%|██████████████▎       | 2600/4000 [04:23<02:32,  9.20it/s]
#
# Running chain 2:  65%|██████████████▎       | 2600/4000 [04:23<02:32,  9.20it/s]
# Running chain 1:  65%|██████████████▎       | 2600/4000 [04:23<02:33,  9.11it/s]
#
#
# Running chain 0:  70%|███████████████▍      | 2800/4000 [04:47<02:15,  8.85it/s]
# Running chain 1:  70%|███████████████▍      | 2800/4000 [04:47<02:15,  8.85it/s]
#
# Running chain 2:  70%|███████████████▍      | 2800/4000 [04:48<02:15,  8.86it/s]
#
#
# Running chain 3:  70%|███████████████▍      | 2800/4000 [04:48<02:14,  8.90it/s]
#
# Running chain 2:  75%|████████████████▌     | 3000/4000 [05:11<01:53,  8.82it/s]
# Running chain 0:  75%|████████████████▌     | 3000/4000 [05:11<01:53,  8.78it/s]
#
#
# Running chain 3:  75%|████████████████▌     | 3000/4000 [05:11<01:53,  8.84it/s]
#
# Running chain 0:  80%|█████████████████▌    | 3200/4000 [05:34<01:31,  8.77it/s]
# Running chain 1:  80%|█████████████████▌    | 3200/4000 [05:34<01:31,  8.76it/s]
#
#
# Running chain 3:  80%|█████████████████▌    | 3200/4000 [05:34<01:30,  8.84it/s]

# %%
az.summary(trace)
# Out:
#                   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# alpha[0]        -0.032  1.180  -1.653    3.120      0.498    0.372       7.0
# alpha[1]         0.386  1.637  -2.066    3.035      0.781    0.594       5.0
# age_effectf[0]  -0.187  1.329  -3.749    1.545      0.571    0.428       6.0
# age_effectf[1]  -0.165  1.295  -3.700    1.454      0.560    0.420       6.0
# age_effectf[2]  -0.141  1.260  -3.722    1.316      0.547    0.411       6.0
# age_effectf[3]  -0.118  1.223  -3.610    1.321      0.534    0.401       6.0
# age_effectf[4]  -0.093  1.185  -3.589    1.178      0.519    0.390       6.0
# age_effectf[5]  -0.070  1.147  -3.486    1.120      0.504    0.379       6.0
# age_effectf[6]  -0.046  1.108  -3.332    1.129      0.489    0.368       6.0
# age_effectf[7]  -0.024  1.069  -3.154    1.144      0.473    0.356       6.0
# age_effectf[8]  -0.003  1.030  -3.038    1.131      0.458    0.344       6.0
# age_effectf[9]   0.016  0.992  -2.770    1.252      0.442    0.333       6.0
# age_effectf[10]  0.033  0.954  -2.483    1.364      0.426    0.321       6.0
# age_effectf[11]  0.048  0.918  -2.329    1.360      0.411    0.310       6.0
# age_effectf[12]  0.062  0.882  -2.257    1.297      0.396    0.298       6.0
# age_effectf[13]  0.073  0.849  -2.128    1.283      0.381    0.287       6.0
# age_effectf[14]  0.082  0.817  -2.027    1.225      0.367    0.276       6.0
# age_effectf[15]  0.089  0.788  -1.947    1.176      0.353    0.266       7.0
# age_effectf[16]  0.095  0.762  -1.921    1.116      0.339    0.255       7.0
# age_effectf[17]  0.098  0.741  -1.833    1.134      0.325    0.245       7.0
# age_effectf[18]  0.101  0.723  -1.636    1.267      0.313    0.234       7.0
# age_effectf[19]  0.102  0.711  -1.463    1.357      0.300    0.224       7.0
# age_effectm[0]  -1.044  2.061  -4.730    1.719      0.994    0.768       5.0
# age_effectm[1]  -0.905  2.007  -4.370    1.749      0.973    0.754       5.0
# age_effectm[2]  -0.749  1.939  -3.913    1.816      0.944    0.730       5.0
# age_effectm[3]  -0.577  1.857  -3.503    1.879      0.905    0.698       5.0
# age_effectm[4]  -0.389  1.760  -3.106    1.955      0.858    0.657       5.0
# age_effectm[5]  -0.188  1.649  -2.641    2.079      0.803    0.613       5.0
# age_effectm[6]   0.022  1.526  -2.228    2.166      0.741    0.565       5.0
# age_effectm[7]   0.241  1.396  -1.751    2.247      0.675    0.515       5.0
# age_effectm[8]   0.464  1.265  -1.186    2.363      0.609    0.463       5.0
# age_effectm[9]   0.689  1.144  -0.719    2.430      0.547    0.418       5.0
# age_effectm[10]  0.914  1.047  -0.541    2.552      0.498    0.384       5.0
# age_effectm[11]  1.134  0.990  -0.484    2.655      0.470    0.362       5.0
# age_effectm[12]  1.347  0.987  -0.415    2.775      0.468    0.359       5.0
# age_effectm[13]  1.552  1.038  -0.350    2.877      0.495    0.377       5.0
# age_effectm[14]  1.745  1.134  -0.291    2.979      0.543    0.414       5.0
# age_effectm[15]  1.924  1.259  -0.212    3.502      0.605    0.462       5.0
# age_effectm[16]  2.088  1.399  -0.166    4.117      0.674    0.514       5.0
# age_effectm[17]  2.235  1.541  -0.251    4.595      0.743    0.567       5.0
# age_effectm[18]  2.364  1.679  -0.398    4.944      0.808    0.615       5.0
# age_effectm[19]  2.473  1.808  -0.392    5.415      0.867    0.660       5.0
# eta[0]           0.654  0.656   0.001    1.938      0.206    0.150      14.0
# eta[1]           0.831  0.627   0.028    1.958      0.158    0.114      14.0
# sigma[0]         1.085  1.025   0.112    2.952      0.354    0.259       8.0
# sigma[1]         2.545  1.468   0.438    5.269      0.526    0.387       8.0
# rho[0]           0.909  0.082   0.758    1.000      0.004    0.003     331.0
# rho[1]           0.909  0.080   0.764    1.000      0.004    0.003     375.0
#
#                  ess_tail  r_hat
# alpha[0]             11.0   1.53
# alpha[1]             57.0   2.51
# age_effectf[0]       11.0   1.72
# age_effectf[1]       11.0   1.71
# age_effectf[2]       11.0   1.74
# age_effectf[3]       11.0   1.80
# age_effectf[4]       11.0   1.83
# age_effectf[5]       11.0   1.86
# age_effectf[6]       11.0   1.87
# age_effectf[7]       11.0   1.88
# age_effectf[8]       11.0   1.86
# age_effectf[9]       12.0   1.82
# age_effectf[10]      12.0   1.75
# age_effectf[11]      12.0   1.75
# age_effectf[12]      12.0   1.74
# age_effectf[13]      12.0   1.72
# age_effectf[14]      12.0   1.69
# age_effectf[15]      11.0   1.67
# age_effectf[16]      11.0   1.64
# age_effectf[17]      11.0   1.61
# age_effectf[18]      11.0   1.58
# age_effectf[19]      12.0   1.55
# age_effectm[0]       13.0   2.80
# age_effectm[1]       13.0   2.86
# age_effectm[2]       13.0   2.90
# age_effectm[3]       21.0   2.76
# age_effectm[4]       19.0   2.71
# age_effectm[5]       17.0   2.85
# age_effectm[6]       17.0   2.96
# age_effectm[7]       18.0   3.03
# age_effectm[8]       19.0   2.93
# age_effectm[9]       30.0   2.67
# age_effectm[10]      15.0   2.60
# age_effectm[11]      15.0   2.45
# age_effectm[12]      15.0   2.75
# age_effectm[13]      14.0   2.78
# age_effectm[14]      13.0   2.61
# age_effectm[15]      13.0   2.62
# age_effectm[16]      12.0   2.93
# age_effectm[17]      13.0   2.84
# age_effectm[18]      18.0   2.72
# age_effectm[19]      22.0   2.62
# eta[0]               30.0   1.23
# eta[1]              124.0   1.21
# sigma[0]             26.0   1.51
# sigma[1]             65.0   1.47
# rho[0]              581.0   1.01
# rho[1]              759.0   1.01

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 d_berlin.index()
#
# TypeError: 'RangeIndex' object is not callable
